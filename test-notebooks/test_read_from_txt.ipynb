# %%
from pathlib import Path
import chardet
import re

# %%
book_file = Path(r'/Users/jeremy/Development/family-altar-book-processor/Book 1 Complete.txt')
output_folder = Path("processed_books")
output_folder.mkdir(exist_ok=True)  # Create folder if it doesn't exist
output_file = output_folder / "text-file-creation-test.txt"

def read_book(file_path: Path) -> str:
    """Read the book text into a string, auto-detecting encoding"""
    raw_data = file_path.read_bytes()
    result = chardet.detect(raw_data)
    encoding = result['encoding']
    confidence = result['confidence']
    print(f"Detected encoding: {encoding} (confidence: {confidence:.2f})")
    text = raw_data.decode(encoding).strip()
    # Remove extra blank lines
    lines = [line.strip() for line in text.splitlines() if line.strip()]
    return "\n".join(lines)

if __name__ == "__main__":
    if book_file.exists():
        text = read_book(book_file)
        with output_file.open("w", encoding="utf-8") as f:
            f.write(text)
    else:
        print(f"File not found: {book_file}")
# Out:
# Detected encoding: UTF-16 (confidence: 1.00)

# %%
def find_family_altar_lines(text: str):
    """Find all lines like 'Day {number}    The Family Altar    {Month} {number}'"""
    pattern = re.compile(
        r'Day\s+\d+\s+The Family Altar\s+(January|February|March|April|May|June|July|August|September|October|November|December)\s+\d+',
        re.IGNORECASE
    )
    return pattern.findall(text), pattern.findall(text, re.MULTILINE)  # returns matches

if __name__ == "__main__":
    if book_file.exists():
        text = read_book(book_file)
        matches = re.findall(
            r'Day\s+\d+\s+The Family Altar\s+(?:January|February|March|April|May|June|July|August|September|October|November|December)\s+\d+',
            text
        )
        print("Found lines:")
        for line in matches:
            print(line)
    else:
        print(f"File not found: {book_file}")
# Out:
# Detected encoding: UTF-16 (confidence: 1.00)
# Found lines:
# Day 1                        The Family Altar                     January 1
# Day 2                        The Family Altar                     January 2
# Day 3                        The Family Altar                     January 3
# Day 4                        The Family Altar                     January 4
# Day 5                        The Family Altar                     January 5
# Day 6                        The Family Altar                     January 6
# Day 7                        The Family Altar                     January 7
# Day 8                        The Family Altar                     January 8
# Day 9                        The Family Altar                     January 9
# Day 10                       The Family Altar                    January 10
# Day 11                       The Family Altar                    January 11
# Day 12                       The Family Altar                    January 12
# Day 13                       The Family Altar                    January 13
# Day 14                       The Family Altar                    January 14
# Day 15                       The Family Altar                    January 15
# Day 16                       The Family Altar                    January 16
# Day 17                       The Family Altar                    January 17
# Day 18                       The Family Altar                    January 18
# Day 19                       The Family Altar                    January 19
# Day 20                       The Family Altar                    January 20
# Day 21                       The Family Altar                    January 21
# Day 22                       The Family Altar                    January 22
# Day 23                       The Family Altar                    January 23
# Day 24                       The Family Altar                    January 24
# Day 25                       The Family Altar                    January 25
# Day 26                       The Family Altar                    January 26
# Day 27                       The Family Altar                    January 27
# Day 28                       The Family Altar                    January 28
# Day 29                       The Family Altar                    January 29
# Day 30                       The Family Altar                    January 30
# Day 31                       The Family Altar                    January 31
# Day 32                       The Family Altar                    February 1
# Day 33                       The Family Altar                    February 2
# Day 34                       The Family Altar                    February 3
# Day 35                       The Family Altar                    February 4
# Day 36                       The Family Altar                    February 5
# Day 37                       The Family Altar                    February 6
# Day 38                       The Family Altar                    February 7
# Day 39                       The Family Altar                    February 8
# Day 40                       The Family Altar                    February 9
# Day 41                       The Family Altar                   February 10
# Day 296                      The Family Altar                    October 22
# Day 297                      The Family Altar                    October 23
# Day 298                      The Family Altar                    October 24
# Day 299                      The Family Altar                    October 25
# Day 300                      The Family Altar                    October 26
# Day 301                      The Family Altar                    October 27
# Day 302                      The Family Altar                    October 28
# Day 303                      The Family Altar                    October 29
# Day 304                      The Family Altar                    October 30
# Day 305                      The Family Altar                    October 31
# Day 306                      The Family Altar                    November 1
# Day 307                      The Family Altar                    November 2
# Day 308                      The Family Altar                    November 3
# Day 309                      The Family Altar                    November 4
# Day 310                      The Family Altar                    November 5
# Day 311                      The Family Altar                    November 6
# Day 312                      The Family Altar                    November 7
# Day 313                      The Family Altar                    November 8
# Day 314                      The Family Altar                    November 9
# Day 315                      The Family Altar                   November 10
# Day 316                      The Family Altar                   November 11
# Day 317                      The Family Altar                   November 12
# Day 318                      The Family Altar                   November 13
# Day 319                      The Family Altar                   November 14
# Day 320                      The Family Altar                   November 15
# Day 321                      The Family Altar                   November 16
# Day 322                      The Family Altar                   November 17
# Day 323                      The Family Altar                   November 18
# Day 324                      The Family Altar                   November 19
# Day 325                      The Family Altar                   November 20
# Day 326                      The Family Altar                   November 21
# Day 327                      The Family Altar                   November 22
# Day 328                      The Family Altar                   November 23
# Day 329                      The Family Altar                   November 24
# Day 330                      The Family Altar                   November 25
# Day 331                      The Family Altar                   November 26
# Day 332                      The Family Altar                   November 27
# Day 333                      The Family Altar                   November 28
# Day 334                      The Family Altar                   November 29
# Day 335                      The Family Altar                   November 30
# Day 336                      The Family Altar                    December 1
# Day 337                      The Family Altar                    December 2
# Day 338                      The Family Altar                    December 3
# Day 339                      The Family Altar                    December 4
# Day 340                      The Family Altar                    December 5
# Day 341                      The Family Altar                    December 6
# Day 342                      The Family Altar                    December 7
# Day 343                      The Family Altar                    December 8
# Day 344                      The Family Altar                    December 9
# Day 345                      The Family Altar                   December 10
# Day 346                      The Family Altar                   December 11
# Day 347                      The Family Altar                   December 12
# Day 348                      The Family Altar                   December 13
# Day 349                      The Family Altar                   December 14
# Day 350                      The Family Altar                   December 15
# Day 351                      The Family Altar                   December 16
# Day 352                      The Family Altar                   December 17
# Day 353                      The Family Altar                   December 18
# Day 354                      The Family Altar                   December 19
# Day 355                      The Family Altar                   December 20
# Day 356                      The Family Altar                   December 21
# Day 357                      The Family Altar                   December 22
# Day 358                      The Family Altar                   December 23
# Day 359                      The Family Altar                   December 24
# Day 360                      The Family Altar                   December 25
# Day 361                      The Family Altar                   December 26
# Day 362                      The Family Altar                   December 27
# Day 363                      The Family Altar                   December 28
# Day 364                      The Family Altar                   December 29
# Day 365                      The Family Altar                   December 30
# Day 366                      The Family Altar                   December 31

# %%
import re
from pathlib import Path

def save_days_to_files(book_text: str, output_folder: Path):
    """
    Split the Family Altar book text into daily sections and save each one as a separate file.
    Each file is named after the date on that page (e.g. 'January_6.txt').
    """
    output_folder.mkdir(exist_ok=True)

    # Pattern to match the start of each day's entry
    pattern = re.compile(
        r'(Day\s+\d+\s+The Family Altar\s+(January|February|March|April|May|June|July|August|September|October|November|December)\s+\d+)',
        re.IGNORECASE
    )

    # Find all start positions of each day's heading
    matches = list(pattern.finditer(book_text))

    for i, match in enumerate(matches):
        start = match.start()
        end = matches[i + 1].start() if i + 1 < len(matches) else len(book_text)

        # Extract the day's full text block
        day_text = book_text[start:end].strip()

        # Extract the month and day number for naming
        heading = match.group(1)
        date_match = re.search(r'(January|February|March|April|May|June|July|August|September|October|November|December)\s+(\d+)', heading)
        if date_match:
            month = date_match.group(1)
            day = date_match.group(2)
            filename = f"{month}_{day}.txt"
        else:
            filename = f"day_{i+1}.txt"

        # Save the section to a file
        output_path = output_folder / filename
        with open(output_path, "w", encoding="utf-8") as f:
            f.write(day_text)

        print(f"Saved: {filename}")

if __name__ == "__main__":
    output_folder = Path("days")

    if book_file.exists():
        text = read_book(book_file)
        save_days_to_files(text, output_folder)
    else:
        print(f"File not found: {book_file}")
# Out:
# Detected encoding: UTF-16 (confidence: 1.00)
# Saved: January_1.txt
# Saved: January_2.txt
# Saved: January_3.txt
# Saved: January_4.txt
# Saved: January_5.txt
# Saved: January_6.txt
# Saved: January_7.txt
# Saved: January_8.txt
# Saved: January_9.txt
# Saved: January_10.txt
# Saved: January_11.txt
# Saved: January_12.txt
# Saved: January_13.txt
# Saved: January_14.txt
# Saved: January_15.txt
# Saved: January_16.txt
# Saved: January_17.txt
# Saved: January_18.txt
# Saved: January_19.txt
# Saved: January_20.txt
# Saved: January_21.txt
# Saved: January_22.txt
# Saved: January_23.txt
# Saved: January_24.txt
# Saved: January_25.txt
# Saved: January_26.txt
# Saved: January_27.txt
# Saved: January_28.txt
# Saved: January_29.txt
# Saved: January_30.txt
# Saved: January_31.txt
# Saved: February_1.txt
# Saved: February_2.txt
# Saved: February_3.txt
# Saved: February_4.txt
# Saved: February_5.txt
# Saved: February_6.txt
# Saved: February_7.txt
# Saved: February_8.txt
# Saved: February_9.txt
# Saved: February_10.txt
# Saved: February_11.txt
# Saved: February_12.txt
# Saved: February_13.txt
# Saved: February_14.txt
# Saved: February_15.txt
# Saved: February_16.txt
# Saved: February_17.txt
# Saved: February_18.txt
# Saved: February_19.txt
# Saved: February_20.txt
# Saved: February_21.txt
# Saved: February_22.txt
# Saved: February_23.txt
# Saved: February_24.txt
# Saved: February_25.txt
# Saved: February_26.txt
# Saved: February_27.txt
# Saved: February_28.txt
# Saved: February_29.txt
# Saved: March_1.txt
# Saved: March_2.txt
# Saved: March_3.txt
# Saved: March_4.txt
# Saved: March_5.txt
# Saved: March_6.txt
# Saved: March_7.txt
# Saved: March_8.txt
# Saved: March_9.txt
# Saved: March_10.txt
# Saved: March_11.txt
# Saved: March_12.txt
# Saved: March_13.txt
# Saved: March_14.txt
# Saved: March_15.txt
# Saved: March_16.txt
# Saved: March_17.txt
# Saved: March_18.txt
# Saved: March_19.txt
# Saved: March_20.txt
# Saved: March_21.txt
# Saved: March_22.txt
# Saved: March_23.txt
# Saved: March_24.txt
# Saved: March_25.txt
# Saved: March_26.txt
# Saved: March_27.txt
# Saved: March_28.txt
# Saved: March_29.txt
# Saved: March_30.txt
# Saved: March_31.txt
# Saved: April_1.txt
# Saved: April_2.txt
# Saved: April_3.txt
# Saved: April_4.txt
# Saved: April_5.txt
# Saved: April_6.txt
# Saved: April_7.txt
# Saved: April_8.txt
# Saved: April_9.txt
# Saved: April_10.txt
# Saved: April_11.txt
# Saved: April_12.txt
# Saved: April_13.txt
# Saved: April_14.txt
# Saved: April_15.txt
# Saved: April_16.txt
# Saved: April_17.txt
# Saved: April_18.txt
# Saved: April_19.txt
# Saved: April_20.txt
# Saved: April_21.txt
# Saved: April_22.txt
# Saved: April_23.txt
# Saved: April_24.txt
# Saved: April_25.txt
# Saved: April_26.txt
# Saved: April_27.txt
# Saved: April_28.txt
# Saved: April_29.txt
# Saved: April_30.txt
# Saved: May_1.txt
# Saved: May_2.txt
# Saved: May_3.txt
# Saved: May_4.txt
# Saved: May_5.txt
# Saved: May_6.txt
# Saved: May_7.txt
# Saved: May_8.txt
# Saved: May_9.txt
# Saved: May_10.txt
# Saved: May_11.txt
# Saved: May_12.txt
# Saved: May_13.txt
# Saved: May_14.txt
# Saved: May_15.txt
# Saved: May_16.txt
# Saved: May_17.txt
# Saved: May_18.txt
# Saved: May_19.txt
# Saved: May_20.txt
# Saved: May_21.txt
# Saved: May_22.txt
# Saved: May_23.txt
# Saved: May_24.txt
# Saved: May_25.txt
# Saved: May_26.txt
# Saved: May_27.txt
# Saved: May_28.txt
# Saved: May_29.txt
# Saved: May_30.txt
# Saved: May_31.txt
# Saved: June_1.txt
# Saved: June_2.txt
# Saved: June_3.txt
# Saved: June_4.txt
# Saved: June_5.txt
# Saved: June_6.txt
# Saved: June_7.txt
# Saved: June_8.txt
# Saved: June_9.txt
# Saved: June_10.txt
# Saved: June_11.txt
# Saved: June_12.txt
# Saved: June_13.txt
# Saved: June_14.txt
# Saved: June_15.txt
# Saved: June_16.txt
# Saved: June_17.txt
# Saved: June_18.txt
# Saved: June_19.txt
# Saved: June_20.txt
# Saved: June_21.txt
# Saved: June_22.txt
# Saved: June_23.txt
# Saved: June_24.txt
# Saved: June_25.txt
# Saved: June_26.txt
# Saved: June_27.txt
# Saved: June_28.txt
# Saved: June_29.txt
# Saved: June_30.txt
# Saved: July_1.txt
# Saved: July_2.txt
# Saved: July_3.txt
# Saved: July_4.txt
# Saved: July_5.txt
# Saved: July_6.txt
# Saved: July_7.txt
# Saved: July_8.txt
# Saved: July_9.txt
# Saved: July_10.txt
# Saved: July_11.txt
# Saved: July_12.txt
# Saved: July_13.txt
# Saved: July_14.txt
# Saved: July_15.txt
# Saved: July_16.txt
# Saved: July_17.txt
# Saved: July_18.txt
# Saved: July_19.txt
# Saved: July_20.txt
# Saved: July_21.txt
# Saved: July_22.txt
# Saved: July_23.txt
# Saved: July_24.txt
# Saved: July_25.txt
# Saved: July_26.txt
# Saved: July_27.txt
# Saved: July_28.txt
# Saved: July_29.txt
# Saved: July_30.txt
# Saved: July_31.txt
# Saved: August_1.txt
# Saved: August_2.txt
# Saved: August_3.txt
# Saved: August_4.txt
# Saved: August_5.txt
# Saved: August_6.txt
# Saved: August_7.txt
# Saved: August_8.txt
# Saved: August_9.txt
# Saved: August_10.txt
# Saved: August_11.txt
# Saved: August_12.txt
# Saved: August_13.txt
# Saved: August_14.txt
# Saved: August_15.txt
# Saved: August_16.txt
# Saved: August_17.txt
# Saved: August_18.txt
# Saved: August_19.txt
# Saved: August_20.txt
# Saved: August_21.txt
# Saved: August_22.txt
# Saved: August_23.txt
# Saved: August_24.txt
# Saved: August_25.txt
# Saved: August_26.txt
# Saved: August_27.txt
# Saved: August_28.txt
# Saved: August_29.txt
# Saved: August_30.txt
# Saved: August_31.txt
# Saved: September_1.txt
# Saved: September_2.txt
# Saved: September_3.txt
# Saved: September_4.txt
# Saved: September_5.txt
# Saved: September_6.txt
# Saved: September_7.txt
# Saved: September_8.txt
# Saved: September_9.txt
# Saved: September_10.txt
# Saved: September_11.txt
# Saved: September_12.txt
# Saved: September_13.txt
# Saved: September_14.txt
# Saved: September_15.txt
# Saved: September_16.txt
# Saved: September_17.txt
# Saved: September_18.txt
# Saved: September_19.txt
# Saved: September_20.txt
# Saved: September_21.txt
# Saved: September_22.txt
# Saved: September_23.txt
# Saved: September_24.txt
# Saved: September_25.txt
# Saved: September_26.txt
# Saved: September_27.txt
# Saved: September_28.txt
# Saved: September_29.txt
# Saved: September_30.txt
# Saved: October_1.txt
# Saved: October_2.txt
# Saved: October_3.txt
# Saved: October_4.txt
# Saved: October_5.txt
# Saved: October_6.txt
# Saved: October_7.txt
# Saved: October_8.txt
# Saved: October_9.txt
# Saved: October_10.txt
# Saved: October_11.txt
# Saved: October_12.txt
# Saved: October_13.txt
# Saved: October_14.txt
# Saved: October_15.txt
# Saved: October_16.txt
# Saved: October_17.txt
# Saved: October_18.txt
# Saved: October_19.txt
# Saved: October_20.txt
# Saved: October_21.txt
# Saved: October_22.txt
# Saved: October_23.txt
# Saved: October_24.txt
# Saved: October_25.txt
# Saved: October_26.txt
# Saved: October_27.txt
# Saved: October_28.txt
# Saved: October_29.txt
# Saved: October_30.txt
# Saved: October_31.txt
# Saved: November_1.txt
# Saved: November_2.txt
# Saved: November_3.txt
# Saved: November_4.txt
# Saved: November_5.txt
# Saved: November_6.txt
# Saved: November_7.txt
# Saved: November_8.txt
# Saved: November_9.txt
# Saved: November_10.txt
# Saved: November_11.txt
# Saved: November_12.txt
# Saved: November_13.txt
# Saved: November_14.txt
# Saved: November_15.txt
# Saved: November_16.txt
# Saved: November_17.txt
# Saved: November_18.txt
# Saved: November_19.txt
# Saved: November_20.txt
# Saved: November_21.txt
# Saved: November_22.txt
# Saved: November_23.txt
# Saved: November_24.txt
# Saved: November_25.txt
# Saved: November_26.txt
# Saved: November_27.txt
# Saved: November_28.txt
# Saved: November_29.txt
# Saved: November_30.txt
# Saved: December_1.txt
# Saved: December_2.txt
# Saved: December_3.txt
# Saved: December_4.txt
# Saved: December_5.txt
# Saved: December_6.txt
# Saved: December_7.txt
# Saved: December_8.txt
# Saved: December_9.txt
# Saved: December_10.txt
# Saved: December_11.txt
# Saved: December_12.txt
# Saved: December_13.txt
# Saved: December_14.txt
# Saved: December_15.txt
# Saved: December_16.txt
# Saved: December_17.txt
# Saved: December_18.txt
# Saved: December_19.txt
# Saved: December_20.txt
# Saved: December_21.txt
# Saved: December_22.txt
# Saved: December_23.txt
# Saved: December_24.txt
# Saved: December_25.txt
# Saved: December_26.txt
# Saved: December_27.txt
# Saved: December_28.txt
# Saved: December_29.txt
# Saved: December_30.txt
# Saved: December_31.txt
